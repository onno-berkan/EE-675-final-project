# %%
# load tuning data

# spikePow: take first 128 cols (000-127) -- same for tx1-tx4
    # test KF on all

# goTrialEpochs: use to epoch go trials

# audioEnvelope: use to find exactly when speaking begins and ends

# trialCues: use to group neural data for the same cue
